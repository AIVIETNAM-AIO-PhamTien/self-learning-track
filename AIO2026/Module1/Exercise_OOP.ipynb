# %% [markdown]
# # Exercise: Object Oriented Programming — **Code (Hint)**
# **AI VIET NAM – AIO2026 | Module 01**
#
# Bản **đục lỗ** cho học viên. Hoàn thiện code giữa `### Your Code Here` và `### End Code Here`.
# Ôn lý thuyết OOP: xem **`[Code]-OOP-Review.ipynb`**. Quy ước: **snake_case**, **type hints đầy đủ**.

# %% [markdown]
# ## Bài 1. Xây dựng class tính Sigmoid
# `Sigmoid(x) = 1 / (1 + e^{-x})`. Kế thừa `nn.Module`, ghi đè `forward`.
# > Lưu ý: input phải là tensor **float**.

# %%
import torch
import torch.nn as nn


class MySigmoid(nn.Module):
    def __init__(self) -> None:
        super().__init__()

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        ### Your Code Here
        return 1/ (1 + torch.exp(-x))
        ### End Code Here


my_sigmoid = MySigmoid()
x = torch.tensor([1.0, 5.0, -4.0, 3.0, -2.0])
print(my_sigmoid(x))
# Mong doi: tensor([0.7311, 0.9933, 0.0180, 0.9526, 0.1192])
# Out:
# tensor([0.7311, 0.9933, 0.0180, 0.9526, 0.1192])

# %% [markdown]
# ## Bài 2. Xây dựng Ward (Person / Student / Teacher / Doctor)
# Hoàn thiện `__init__` + `describe` cho 3 lớp con, rồi hoàn thiện các method của `Ward`.

# %%
from abc import ABC, abstractmethod


class Person(ABC):
    def __init__(self, name: str, yob: int) -> None:
        self._name = name
        self._yob = yob

    def get_yob(self) -> int:
        return self._yob

    def __lt__(self, other: "Person") -> bool:   # da co san: so sanh theo yob
        return self._yob < other._yob

    @abstractmethod
    def describe(self) -> None:
        pass


class Student(Person):
    def __init__(self, name: str, yob: int, grade: str) -> None:
        ### Your Code Here
        super().__init__(name, yob)
        self._grade = grade
        ### End Code Here

    def __str__(self) -> str:
        ### Your Code Here
        return f"Name: {self._name}- YoB: {self._yob}- Grade: {self._grade}"
        ### End Code Here

    def describe(self) -> None:
        print(self)            # dung __str__


class Teacher(Person):
    def __init__(self, name: str, yob: int, subject: str) -> None:
        ### Your Code Here
        super().__init__(name, yob)
        self._subject = subject
        ### End Code Here

    def __str__(self) -> str:
        ### Your Code Here
        return f"Name: {self._name}- YoB: {self._yob}- Subject: {self._subject}"
        ### End Code Here

    def describe(self) -> None:
        print(self)


class Doctor(Person):
    def __init__(self, name: str, yob: int, specialist: str) -> None:
        ### Your Code Here
        super().__init__(name, yob)
        self._specialist = specialist
        ### End Code Here

    def __str__(self) -> str:
        ### Your Code Here
        return f"Name: {self._name}- YoB: {self._yob}- Specialist: {self._specialist}"
        ### End Code Here

    def describe(self) -> None:
        print(self)

# %%
class Ward:
    def __init__(self, name: str) -> None:
        self.__name = name
        self.__list_people: list[Person] = list()

    def add_person(self, person: Person) -> None:
        self.__list_people.append(person)

    def describe(self) -> None:
        ### Your Code Here
        print(f"Ward Name: {self.__name }")
        for people in self.__list_people:
          people.describe()
        ### End Code Here

    def count_doctor(self) -> int:
        ### Your Code Here
        count = 0
        for person in self.__list_people:
          if isinstance(person, Doctor):
            count += 1
        return count
        ### End Code Here

    def sort_age(self) -> None:
        ### Your Code Here
        self.__list_people.sort(reverse = True)
        ### End Code Here

    def average_teacher_yob(self) -> float:
        ### Your Code Here
        total_year = 0
        counter = 0
        for person in self.__list_people:
          if isinstance(person, Teacher):
            counter += 1
            total_year += person.get_yob()
        return total_year / counter
        ### End Code Here

# %%
student1 = Student(name="studentA", yob=2010, grade="7")
teacher1 = Teacher(name="teacherA", yob=1969, subject="Math")
teacher2 = Teacher(name="teacherB", yob=1995, subject="History")
doctor1 = Doctor(name="doctorA", yob=1945, specialist="Endocrinologists")
doctor2 = Doctor(name="doctorB", yob=1975, specialist="Cardiologists")

ward1 = Ward(name="Ward1")
for person in [student1, teacher1, teacher2, doctor1, doctor2]:
    ward1.add_person(person)
ward1.describe()

print(f"\nNumber of doctors: {ward1.count_doctor()}")

print("\nAfter sorting Age of Ward1 people")
ward1.sort_age()
ward1.describe()

print(f"\nAverage year of birth (teachers): {ward1.average_teacher_yob()}")
# Out:
# Ward Name: Ward1
# Name: studentA- YoB: 2010- Grade: 7
# Name: teacherA- YoB: 1969- Subject: Math
# Name: teacherB- YoB: 1995- Subject: History
# Name: doctorA- YoB: 1945- Specialist: Endocrinologists
# Name: doctorB- YoB: 1975- Specialist: Cardiologists
#
# Number of doctors: 2
#
# After sorting Age of Ward1 people
# Ward Name: Ward1
# Name: studentA- YoB: 2010- Grade: 7
# Name: teacherB- YoB: 1995- Subject: History
# Name: doctorB- YoB: 1975- Specialist: Cardiologists
# Name: teacherA- YoB: 1969- Subject: Math
# Name: doctorA- YoB: 1945- Specialist: Endocrinologists
#
# Average year of birth (teachers): 1982.0

# %% [markdown]
# ## Bài 3. Xây dựng class Stack (LIFO)
# `__init__` và `is_full` đã có sẵn làm mẫu. Hoàn thiện `is_empty`, `push`, `pop`, `top`.

# %%
from typing import Optional


class MyStack:
    def __init__(self, capacity: int) -> None:
        self.__capacity = capacity
        self.__stack: list[int] = []

    def is_full(self) -> bool:
        return len(self.__stack) == self.__capacity

    def is_empty(self) -> bool:
        ### Your Code Here
        return len(self.__stack) == 0
        ### End Code Here

    def push(self, value: int) -> None:
        ### Your Code Here
        self.__stack.append(value)
        ### End Code Here

    def pop(self) -> int:
        ### Your Code Here
        temp = self.__stack[-1]
        del self.__stack[-1]
        return temp
        ### End Code Here

    def top(self) -> Optional[int]:
        ### Your Code Here
        return self.__stack[-1]
        ### End Code Here

    def __len__(self) -> int:
        ### Your Code Here
        return len(self.__stack)
        ### End Code Here

    def __repr__(self) -> str:
        ### Your Code Here
        return f"MyStack({self.__stack})"
        ### End Code Here

# %%
stack1 = MyStack(capacity=5)
stack1.push(1)
stack1.push(2)

print(stack1.is_full())   # False
print(stack1.top())       # 2
print(stack1.pop())       # 2
print(stack1.top())       # 1
print(stack1.pop())       # 1
print(stack1.is_empty())  # True
# Out:
# False
# 2
# 2
# 1
# 1
# True

# %% [markdown]
# ## Bài 4. Xây dựng class Queue (FIFO)
# `__init__` và `is_full` đã có sẵn làm mẫu. Hoàn thiện `is_empty`, `enqueue`, `dequeue`, `front`.

# %%
from typing import Optional


class MyQueue:
    def __init__(self, capacity: int) -> None:
        self.__capacity = capacity
        self.__queue: list[int] = []

    def is_full(self) -> bool:
        return len(self.__queue) == self.__capacity

    def is_empty(self) -> bool:
        ### Your Code Here
        return len(self.__queue) == 0
        ### End Code Here

    def enqueue(self, value: int) -> None:
        ### Your Code Here
        self.__queue.append(value)
        ### End Code Here

    def dequeue(self) -> int:
        ### Your Code Here
        temp = self.__queue[0]
        del self.__queue[0]
        return temp
        ### End Code Here

    def front(self) -> Optional[int]:
        ### Your Code Here
        return self.__queue[0]
        ### End Code Here

    def __len__(self) -> int:
        ### Your Code Here
        return len(self.__queue)
        ### End Code Here

    def __repr__(self) -> str:
        ### Your Code Here
        return f"MyQueue({self.__queue})"
        ### End Code Here

# %%
queue1 = MyQueue(capacity=5)
queue1.enqueue(1)
queue1.enqueue(2)

print(queue1.is_full())   # False
print(queue1.front())     # 1
print(queue1.dequeue())   # 1
print(queue1.front())     # 2
print(queue1.dequeue())   # 2
print(queue1.is_empty())  # True
# Out:
# False
# 1
# 1
# 2
# 2
# True

# %% [markdown]
# ## Thử thách thêm (optional)
# Vận dụng Stack/Queue đã viết để giải 2 bài ứng dụng nhỏ.

# %%
# Thu thach 1 (Stack): kiem tra ngoac can bang () [] {}
def is_balanced(text: str) -> bool:
    pairs = {")": "(", "]": "[", "}": "{"}
    stack = MyStack(capacity=len(text) + 1)
    ### Your Code Here
    for char in text:
      if char in "([{":
        stack.push(char)

      elif char in pairs:
        if stack.is_empty():
          return False

        top = stack.pop()

        if top != pairs[char]:
          return False

    return stack.is_empty()
    ### End Code Here

print(is_balanced("(a[b]{c})"))   # mong doi: True
print(is_balanced("(a[b)c]"))     # mong doi: False
# Out:
# True
# False

# %%
# Thu thach 2 (Queue): mo phong hang doi may in theo thu tu FIFO
def printer_simulation(jobs: list[str]) -> None:
    queue = MyQueue(capacity=len(jobs) + 1)
    ### Your Code Here
    for job in jobs:
      queue.enqueue(job)
      print(f"[Nhan] them vao hang doi: {job}  ->  {queue}")

    print("--- Bat dau in ---")
    while not queue.is_empty():
        print(f"[In]   dang in: {queue.dequeue()}")
    print("Hoan tat hang doi in.")
    ### End Code Here

printer_simulation(["BaiTap1.pdf", "Slide.pptx", "Anh.png"])
# Out:
# [Nhan] them vao hang doi: BaiTap1.pdf  ->  MyQueue(['BaiTap1.pdf'])
# [Nhan] them vao hang doi: Slide.pptx  ->  MyQueue(['BaiTap1.pdf', 'Slide.pptx'])
# [Nhan] them vao hang doi: Anh.png  ->  MyQueue(['BaiTap1.pdf', 'Slide.pptx', 'Anh.png'])
# --- Bat dau in ---
# [In]   dang in: BaiTap1.pdf
# [In]   dang in: Slide.pptx
# [In]   dang in: Anh.png
# Hoan tat hang doi in.

# %% [markdown]
# ## Mở rộng (tự tìm hiểu)
# Type hints **không** tự kiểm tra kiểu lúc chạy. Muốn kiểm tra runtime, tìm hiểu `pydantic`
# (`BaseModel`, `@validate_call`) — xem mục Mở rộng trong file lời giải.

# %%
from pydantic import BaseModel, validate_call, ValidationError


# (1) BaseModel cho class chua du lieu
class StudentModel(BaseModel):
    name: str
    yob: int
    grade: str


print(StudentModel(name="studentA", yob="2010", grade="7"))  # "2010" -> 2010
try:
    StudentModel(name="studentB", yob="abc", grade="7")       # sai kieu
except ValidationError as e:
    print("ValidationError:", e.errors()[0]["msg"])


# (2) @validate_call cho function/method
@validate_call
def push_checked(value: int) -> None:
    print("pushed:", value)


push_checked(5)
try:
    push_checked("hello")                                     # sai kieu
except ValidationError as e:
    print("ValidationError:", e.errors()[0]["msg"])
# Out:
# name='studentA' yob=2010 grade='7'
# ValidationError: Input should be a valid integer, unable to parse string as an integer
# pushed: 5
# ValidationError: Input should be a valid integer, unable to parse string as an integer
